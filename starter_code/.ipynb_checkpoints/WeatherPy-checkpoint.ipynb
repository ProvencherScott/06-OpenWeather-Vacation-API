# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\scott proveucher\anaconda3\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\scott proveucher\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# you need to do an API call using the lat and longitude because that is what you are given. 
# Here is the beggining of the API call:   

#Base URL shown on website
base_url = "http://api.openweathermap.org/data/2.5/weather?q="
units = "imperial"

#Create list for City which will be used for the loop
city_id = [x for x in range(len(cities))]

# %%
# Create lists to hold information for each city. These are the columns shown in the table for the solution.

cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
temp = []
wind_speed = []

# %%
#Create a loop to loop through each city
#for city in cities:
    #target_url = {base_url + city + "&appid=" + weather_api_key}
    #response = requests.get(target_url)
    #response_json = response.json()
    
print("Beginning Data Retrieval")     
print("-----------------------------")
for city in cities:
    response = requests.get(base_url + city + "&appid=" + weather_api_key + "&units=" + units).json()
    
    try:
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        print(f"Processing Record {cities.index(city) + 1} | {city.title()}")
    except:
        print("City not found. Skipping...")
    time.sleep(2)

                                
#try to print the json
# Out:
# Beginning Data Retrieval
# -----------------------------
# City not found. Skipping...
# Processing Record 2 | Hobart
# Processing Record 3 | Dunedin
# Processing Record 4 | Khatanga
# Processing Record 5 | Maun
# City not found. Skipping...
# Processing Record 7 | Kapaa
# Processing Record 8 | Biltine
# Processing Record 9 | Poum
# Processing Record 10 | College
# Processing Record 11 | Butaritari
# Processing Record 12 | Longyearbyen
# Processing Record 13 | Najran
# Processing Record 14 | Faanui
# Processing Record 15 | Punta Arenas
# Processing Record 16 | Saint-Philippe
# Processing Record 17 | Port Macquarie
# Processing Record 18 | Leningradskiy
# Processing Record 19 | Arraial Do Cabo
# City not found. Skipping...
# Processing Record 21 | Whitehorse
# Processing Record 22 | Nouadhibou
# Processing Record 23 | Atuona
# Processing Record 24 | Ucluelet
# Processing Record 25 | Klaksvik
# Processing Record 26 | Karratha
# Processing Record 27 | Mar Del Plata
# Processing Record 28 | Lorengau
# Processing Record 29 | Bengkulu
# Processing Record 30 | Rikitea
# Processing Record 31 | Ntoum
# Processing Record 32 | Esperance
# Processing Record 33 | Yingcheng
# Processing Record 34 | Carnarvon
# Processing Record 35 | Busselton
# Processing Record 36 | Dikson
# Processing Record 37 | Tasiilaq
# Processing Record 38 | Hobyo
# Processing Record 39 | Sukhothai
# Processing Record 40 | San Cristobal
# Processing Record 41 | Puerto Ayora
# City not found. Skipping...
# Processing Record 43 | Qaqortoq
# Processing Record 44 | Cherskiy
# Processing Record 45 | Hovd
# Processing Record 46 | Luderitz
# City not found. Skipping...
# Processing Record 48 | Lavrentiya
# Processing Record 49 | Tuktoyaktuk
# Processing Record 50 | Pangnirtung
# Processing Record 51 | Jalu
# Processing Record 52 | Filingue
# Processing Record 53 | Mangochi
# Processing Record 54 | Bambous Virieux
# Processing Record 55 | Roma
# City not found. Skipping...
# Processing Record 57 | Mataura
# Processing Record 58 | Padang
# Processing Record 59 | Benjamin Hill
# Processing Record 60 | Hilo
# Processing Record 61 | Hamilton
# Processing Record 62 | Hirara
# Processing Record 63 | Yellowknife
# Processing Record 64 | Nikolskoye
# Processing Record 65 | Bethel
# Processing Record 66 | Chuy
# Processing Record 67 | Blantyre
# Processing Record 68 | Champerico
# Processing Record 69 | Airai
# Processing Record 70 | Torbay
# Processing Record 71 | Avarua
# Processing Record 72 | Albany
# City not found. Skipping...
# Processing Record 74 | San Patricio
# Processing Record 75 | Barrow
# Processing Record 76 | Saskylakh
# Processing Record 77 | Saldanha
# Processing Record 78 | Jamestown
# Processing Record 79 | Castro
# Processing Record 80 | Buala
# Processing Record 81 | Paamiut
# Processing Record 82 | Georgetown
# Processing Record 83 | Kudahuvadhoo
# City not found. Skipping...
# Processing Record 85 | Clyde River
# Processing Record 86 | Srivardhan
# Processing Record 87 | Kavaratti
# Processing Record 88 | Coquimbo
# Processing Record 89 | Sur
# Processing Record 90 | Tuatapere
# Processing Record 91 | Saint-Augustin
# Processing Record 92 | Yumen
# Processing Record 93 | Ushuaia
# Processing Record 94 | Sao Joao Da Barra
# Processing Record 95 | Vanersborg
# Processing Record 96 | Hermanus
# Processing Record 97 | Farafangana
# Processing Record 98 | Cidreira
# Processing Record 99 | Kaitangata
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 102 | Darnah
# Processing Record 103 | Southbridge
# Processing Record 104 | Adrar
# Processing Record 105 | Lompoc
# Processing Record 106 | Sangar
# Processing Record 107 | Aswan
# Processing Record 108 | Geraldton
# Processing Record 109 | Qadian
# Processing Record 110 | Trelew
# Processing Record 111 | Port Elizabeth
# Processing Record 112 | Mayor Pablo Lagerenza
# Processing Record 113 | Praia
# Processing Record 114 | Kuito
# City not found. Skipping...
# Processing Record 116 | Boa Vista
# Processing Record 117 | Kalmar
# Processing Record 118 | Vostok
# Processing Record 119 | Ahuimanu
# Processing Record 120 | Cape Town
# City not found. Skipping...
# Processing Record 122 | Toora-Khem
# Processing Record 123 | Mormugao
# Processing Record 124 | Idlib
# Processing Record 125 | Mayo
# Processing Record 126 | Port Hardy
# Processing Record 127 | Tiksi
# Processing Record 128 | Bredasdorp
# Processing Record 129 | Walvis Bay
# Processing Record 130 | Vaini
# Processing Record 131 | New Norfolk
# Processing Record 132 | Veraval
# Processing Record 133 | Ribeira Grande
# Processing Record 134 | Kizlyar
# City not found. Skipping...
# Processing Record 136 | Qaanaaq
# Processing Record 137 | Alofi
# Processing Record 138 | East London
# Processing Record 139 | Fortuna
# Processing Record 140 | Ancud
# Processing Record 141 | Bereda
# City not found. Skipping...
# Processing Record 143 | Columbus
# Processing Record 144 | Aykhal
# Processing Record 145 | Ilulissat
# Processing Record 146 | Panji
# Processing Record 147 | Pemberton
# Processing Record 148 | Chenghai
# Processing Record 149 | Angoram
# City not found. Skipping...
# Processing Record 151 | Brae
# Processing Record 152 | Leshukonskoye
# Processing Record 153 | Bluff
# Processing Record 154 | High Level
# Processing Record 155 | Elko
# Processing Record 156 | Gewane
# Processing Record 157 | Katsuura
# Processing Record 158 | Liuhe
# Processing Record 159 | Severo-Kurilsk
# Processing Record 160 | Sechura
# Processing Record 161 | Ibipeba
# Processing Record 162 | Jacareacanga
# Processing Record 163 | Flin Flon
# Processing Record 164 | Chokurdakh
# Processing Record 165 | Byron Bay
# Processing Record 166 | Isangel
# Processing Record 167 | Cockburn Town
# Processing Record 168 | Jiazi
# Processing Record 169 | Chekhov
# Processing Record 170 | Guerrero Negro
# Processing Record 171 | Dingle
# Processing Record 172 | Mountain Home
# Processing Record 173 | Mackay
# Processing Record 174 | Nisia Floresta
# Processing Record 175 | Natal
# Processing Record 176 | Sri Aman
# Processing Record 177 | Rio Gallegos
# Processing Record 178 | Upernavik
# Processing Record 179 | Sinnamary
# Processing Record 180 | Nome
# Processing Record 181 | Beringovskiy
# Processing Record 182 | Shahrud
# City not found. Skipping...
# Processing Record 184 | Yaviza
# Processing Record 185 | Channel-Port Aux Basques
# Processing Record 186 | Araucaria
# Processing Record 187 | Rocha
# Processing Record 188 | Ailigandi
# City not found. Skipping...
# Processing Record 190 | Silver City
# City not found. Skipping...
# Processing Record 192 | Dunyapur
# Processing Record 193 | Shelby
# Processing Record 194 | Mullovka
# Processing Record 195 | Thompson
# Processing Record 196 | Guaratuba
# Processing Record 197 | Puri
# Processing Record 198 | Mao
# Processing Record 199 | Arman
# Processing Record 200 | Faya
# Processing Record 201 | Zhigansk
# Processing Record 202 | Mareeba
# Processing Record 203 | Genhe
# Processing Record 204 | Blagoyevo
# City not found. Skipping...
# Processing Record 206 | Vardo
# Processing Record 207 | Maxixe
# Processing Record 208 | Portland
# Processing Record 209 | Matara
# Processing Record 210 | Fort Nelson
# Processing Record 211 | Lagos
# Processing Record 212 | Tripoli
# Processing Record 213 | Shellbrook
# Processing Record 214 | Zabid
# Processing Record 215 | Eureka
# City not found. Skipping...
# Processing Record 217 | Kalmunai
# Processing Record 218 | Shingu
# Processing Record 219 | Banepa
# Processing Record 220 | Meulaboh
# Processing Record 221 | Assiniboia
# Processing Record 222 | Krasnorechenskiy
# Processing Record 223 | Bonfim
# Processing Record 224 | Minab
# Processing Record 225 | Manggar
# Processing Record 226 | Sasykoli
# Processing Record 227 | Aldan
# Processing Record 228 | Vila Franca Do Campo
# Processing Record 229 | Sakakah
# Processing Record 230 | Moindou
# City not found. Skipping...
# Processing Record 232 | Hasaki
# Processing Record 233 | Kahului
# Processing Record 234 | Petropavlovsk-Kamchatskiy
# Processing Record 235 | Gamba
# Processing Record 236 | Rongcheng
# City not found. Skipping...
# Processing Record 238 | Sibolga
# Processing Record 239 | Broken Hill
# Processing Record 240 | Sorland
# Processing Record 241 | Pisco
# Processing Record 242 | Waingapu
# Processing Record 243 | Vila Velha
# Processing Record 244 | Tautira
# Processing Record 245 | Port Alfred
# Processing Record 246 | Otane
# Processing Record 247 | Beloha
# Processing Record 248 | Honningsvag
# Processing Record 249 | Kavieng
# Processing Record 250 | Bambanglipuro
# Processing Record 251 | Praia Da Vitoria
# Processing Record 252 | Bubaque
# Processing Record 253 | Ornskoldsvik
# Processing Record 254 | Lake Havasu City
# Processing Record 255 | Umm Kaddadah
# Processing Record 256 | Benjamin Constant
# Processing Record 257 | Beyneu
# Processing Record 258 | Dong Hoi
# Processing Record 259 | Okhotsk
# Processing Record 260 | Feltre
# Processing Record 261 | Saint George
# Processing Record 262 | Persianovskiy
# Processing Record 263 | Matay
# Processing Record 264 | Suffolk
# Processing Record 265 | Westport
# Processing Record 266 | Ocotlan
# Processing Record 267 | Port Augusta
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 270 | Tambovka
# Processing Record 271 | Victoria
# Processing Record 272 | Half Moon Bay
# Processing Record 273 | Orda
# Processing Record 274 | Eganville
# Processing Record 275 | Trebukhiv
# Processing Record 276 | Panguna
# Processing Record 277 | Srednekolymsk
# Processing Record 278 | Ponta Do Sol
# Processing Record 279 | Tezu
# Processing Record 280 | Dubbo
# Processing Record 281 | Cozumel
# Processing Record 282 | Asau
# Processing Record 283 | Pevek
# Processing Record 284 | San-Pedro
# Processing Record 285 | Mopipi
# City not found. Skipping...
# Processing Record 287 | Coahuayana
# Processing Record 288 | Rawson
# Processing Record 289 | Santa Maria
# Processing Record 290 | Cerro De Pasco
# Processing Record 291 | Wanning
# Processing Record 292 | Makarov
# Processing Record 293 | Vallenar
# Processing Record 294 | Reyes
# City not found. Skipping...
# Processing Record 296 | Miami Beach
# City not found. Skipping...
# Processing Record 298 | Iqaluit
# Processing Record 299 | Kamaishi
# Processing Record 300 | Kihei
# Processing Record 301 | Suntar
# Processing Record 302 | Sitka
# Processing Record 303 | Haines Junction
# Processing Record 304 | Portel
# Processing Record 305 | Roswell
# Processing Record 306 | Souillac
# Processing Record 307 | Hoi An
# Processing Record 308 | Auki
# Processing Record 309 | Alanya
# Processing Record 310 | Bonavista
# Processing Record 311 | Arari
# Processing Record 312 | Santiago Del Estero
# Processing Record 313 | Galesong
# Processing Record 314 | Tual
# Processing Record 315 | Sept-Iles
# Processing Record 316 | Stornoway
# Processing Record 317 | Bowen
# Processing Record 318 | Nabire
# Processing Record 319 | Baiao
# Processing Record 320 | Koindu
# Processing Record 321 | Noumea
# Processing Record 322 | Cuamba
# Processing Record 323 | Visby
# Processing Record 324 | Sumbe
# Processing Record 325 | Hauterive
# Processing Record 326 | Devonport
# Processing Record 327 | Necochea
# Processing Record 328 | Nanortalik
# Processing Record 329 | Hailey
# City not found. Skipping...
# Processing Record 331 | Port Lincoln
# Processing Record 332 | Gat
# Processing Record 333 | Bandarbeyla
# Processing Record 334 | Hambantota
# City not found. Skipping...
# Processing Record 336 | Puerto El Triunfo
# City not found. Skipping...
# Processing Record 338 | Yunhe
# Processing Record 339 | Petawawa
# Processing Record 340 | Kodiak
# Processing Record 341 | Hithadhoo
# City not found. Skipping...
# Processing Record 343 | La Libertad
# Processing Record 344 | Brownsville
# Processing Record 345 | Vagur
# Processing Record 346 | Sisimiut
# Processing Record 347 | Mwinilunga
# Processing Record 348 | Nuevo Ideal
# Processing Record 349 | Sioux Lookout
# Processing Record 350 | Tonj
# Processing Record 351 | Bathsheba
# Processing Record 352 | Olafsvik
# Processing Record 353 | Narsaq
# Processing Record 354 | North Bend
# Processing Record 355 | Salalah
# Processing Record 356 | Turukhansk
# Processing Record 357 | Nuuk
# Processing Record 358 | Seminole
# Processing Record 359 | Mitu
# Processing Record 360 | Paciran
# City not found. Skipping...
# Processing Record 362 | Xuddur
# Processing Record 363 | Portobelo
# City not found. Skipping...
# Processing Record 365 | Dijkot
# Processing Record 366 | Tigil
# Processing Record 367 | Lebu
# Processing Record 368 | Hami
# Processing Record 369 | Muyezerskiy
# Processing Record 370 | Sao Filipe
# Processing Record 371 | Port Hedland
# Processing Record 372 | Henties Bay
# Processing Record 373 | Kasongo-Lunda
# Processing Record 374 | Sedona
# Processing Record 375 | Ulladulla
# Processing Record 376 | Hualmay
# City not found. Skipping...
# Processing Record 378 | Manavalakurichi
# Processing Record 379 | Morant Bay
# City not found. Skipping...
# Processing Record 381 | Provideniya
# Processing Record 382 | Margate
# Processing Record 383 | Grand Gaube
# City not found. Skipping...
# Processing Record 385 | Sambava
# Processing Record 386 | Kavaje
# Processing Record 387 | Chicama
# Processing Record 388 | Berlevag
# Processing Record 389 | Puerto Colombia
# Processing Record 390 | Tiarei
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 393 | Darya Khan
# Processing Record 394 | Cuanajo
# Processing Record 395 | Namibe
# Processing Record 396 | Borogontsy
# Processing Record 397 | Comodoro Rivadavia
# Processing Record 398 | Chapais
# Processing Record 399 | Ayan
# Processing Record 400 | Cayenne
# Processing Record 401 | Narrabri
# Processing Record 402 | Ahipara
# City not found. Skipping...
# Processing Record 404 | Muchkapskiy
# Processing Record 405 | Zigong
# Processing Record 406 | Vidin
# Processing Record 407 | Port Hawkesbury
# Processing Record 408 | Aanekoski
# Processing Record 409 | Nanakuli
# Processing Record 410 | Sungairaya
# Processing Record 411 | Alcaniz
# Processing Record 412 | Kiunga
# Processing Record 413 | Nemuro
# Processing Record 414 | Dukat
# Processing Record 415 | Darvari
# Processing Record 416 | Ostersund
# Processing Record 417 | Husavik
# Processing Record 418 | Sistranda
# Processing Record 419 | Bay Roberts
# Processing Record 420 | Mahebourg
# Processing Record 421 | Dhidhdhoo
# Processing Record 422 | Agadez
# Processing Record 423 | Olinda
# Processing Record 424 | Norman Wells
# Processing Record 425 | Nova Floresta
# Processing Record 426 | Mahajanga
# Processing Record 427 | Leopold
# Processing Record 428 | Avera
# Processing Record 429 | Estelle
# Processing Record 430 | Tanout
# Processing Record 431 | Amapa
# City not found. Skipping...
# Processing Record 433 | Sulangan
# Processing Record 434 | Benguela
# Processing Record 435 | Laguna De Perlas
# Processing Record 436 | Inirida
# Processing Record 437 | Lubao
# Processing Record 438 | Taonan
# Processing Record 439 | Pacific Grove
# Processing Record 440 | Cedral
# Processing Record 441 | Bandar-E Lengeh
# Processing Record 442 | Mujiayingzi
# Processing Record 443 | Leh
# Processing Record 444 | Bud
# Processing Record 445 | Aljezur
# Processing Record 446 | Kungurtug
# Processing Record 447 | Naron
# Processing Record 448 | Abu Samrah
# Processing Record 449 | Richards Bay
# Processing Record 450 | Korla
# Processing Record 451 | Kulunda
# Processing Record 452 | Houston
# Processing Record 453 | Sao Jose Da Coroa Grande
# Processing Record 454 | Neepawa
# Processing Record 455 | Winslow
# Processing Record 456 | Bourail
# Processing Record 457 | Sungaipenuh
# Processing Record 458 | Linden
# Processing Record 459 | Kapustin Yar
# Processing Record 460 | Krasnoselkup
# Processing Record 461 | Kruisfontein
# Processing Record 462 | Taitung
# Processing Record 463 | Chenzhou
# Processing Record 464 | Guiglo
# Processing Record 465 | Takoradi
# City not found. Skipping...
# Processing Record 467 | Taoudenni
# Processing Record 468 | Yulara
# Processing Record 469 | Shenjiamen
# Processing Record 470 | Pirovskoye
# Processing Record 471 | Kirensk
# Processing Record 472 | Pangoa
# Processing Record 473 | Lakes Entrance
# Processing Record 474 | Satka
# Processing Record 475 | Cabo San Lucas
# Processing Record 476 | Kashi
# Processing Record 477 | Manaure
# Processing Record 478 | Pankrushikha
# Processing Record 479 | Lewistown
# Processing Record 480 | Guozhen
# Processing Record 481 | Noshiro
# Processing Record 482 | San Francisco
# Processing Record 483 | Voh
# Processing Record 484 | Labuhan
# Processing Record 485 | Port-Cartier
# Processing Record 486 | Mount Gambier
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 489 | Codrington
# Processing Record 490 | Valle De Allende
# Processing Record 491 | Arlit
# Processing Record 492 | Aklavik
# Processing Record 493 | Sankheda
# Processing Record 494 | Komsomolskiy
# City not found. Skipping...
# Processing Record 496 | Jiaojiang
# Processing Record 497 | Pyaozerskiy
# Processing Record 498 | Marsh Harbour
# Processing Record 499 | Nyrob
# Processing Record 500 | Shelburne
# Processing Record 501 | Tianpeng
# City not found. Skipping...
# Processing Record 503 | Ouadda
# Processing Record 504 | Emerald
# Processing Record 505 | Manta
# Processing Record 506 | Tura
# Processing Record 507 | Phan Thiet
# Processing Record 508 | Lupiro
# Processing Record 509 | Juneau
# Processing Record 510 | Cam Ranh
# Processing Record 511 | Broome
# City not found. Skipping...
# Processing Record 513 | Puerto Escondido
# Processing Record 514 | Biu
# Processing Record 515 | Port Blair
# Processing Record 516 | Kailua
# Processing Record 517 | Porto Novo
# Processing Record 518 | Omboue
# Processing Record 519 | San Pedro
# Processing Record 520 | Camana
# Processing Record 521 | Maragogi
# City not found. Skipping...
# Processing Record 523 | Baruun-Urt
# Processing Record 524 | Alta Floresta
# Processing Record 525 | Kalinovskaya
# Processing Record 526 | Sola
# Processing Record 527 | Oranjemund
# Processing Record 528 | Vestmannaeyjar
# Processing Record 529 | Palu
# Processing Record 530 | Boke
# Processing Record 531 | Baykit
# Processing Record 532 | Moorhead
# Processing Record 533 | Severnoye
# Processing Record 534 | Touros
# Processing Record 535 | Saint-Leu
# Processing Record 536 | Mackenzie
# Processing Record 537 | Pulaski
# Processing Record 538 | Valdivia
# Processing Record 539 | Egvekinot
# Processing Record 540 | Urumqi
# Processing Record 541 | Zhigalovo
# Processing Record 542 | Moron
# Processing Record 543 | Samarai
# Processing Record 544 | Poso
# Processing Record 545 | Port Pirie
# Processing Record 546 | Bonthe
# Processing Record 547 | Mount Isa
# Processing Record 548 | Ngunguru
# Processing Record 549 | Daud Khel
# City not found. Skipping...
# Processing Record 551 | Fajardo
# Processing Record 552 | Kampot
# City not found. Skipping...
# Processing Record 554 | Klyuchi
# Processing Record 555 | Belaya Gora
# Processing Record 556 | Kilindoni
# Processing Record 557 | Novyy Urengoy
# Processing Record 558 | Shakawe
# Processing Record 559 | Diamantino
# Processing Record 560 | Ortakoy
# Processing Record 561 | Chernyshevskiy
# Processing Record 562 | Chalmette
# Processing Record 563 | Atambua
# Processing Record 564 | Bunia
# Processing Record 565 | Shimoda
# Processing Record 566 | Zhezkazgan
# Processing Record 567 | Ojinaga
# Processing Record 568 | Seoul
# Processing Record 569 | Cambridge
# Processing Record 570 | San Policarpo
# Processing Record 571 | Riyadh
# Processing Record 572 | Sokoni
# Processing Record 573 | The Valley
# Processing Record 574 | Bull Savanna
# City not found. Skipping...
# Processing Record 576 | Catemaco
# Processing Record 577 | Kholodnyy
# Processing Record 578 | El Dorado
# Processing Record 579 | Nueva Loja
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 582 | Xicotencatl
# Processing Record 583 | Mazagao
# Processing Record 584 | Maumere
# Processing Record 585 | Oyama
# Processing Record 586 | Zhanaozen
# Processing Record 587 | Mundo Nuevo
# Processing Record 588 | Tecoanapa
# Processing Record 589 | Fengrun
# City not found. Skipping...
# Processing Record 591 | Mehamn
# Processing Record 592 | Coolum Beach
# Processing Record 593 | Parrita
# Processing Record 594 | Udachnyy
# Processing Record 595 | Amursk
# Processing Record 596 | Moreira Sales
# Processing Record 597 | Chama
# Processing Record 598 | Gemena
# Processing Record 599 | Lumberton
# Processing Record 600 | Mahon
# Processing Record 601 | Los Llanos De Aridane
# Processing Record 602 | Santa Clarita
# Processing Record 603 | Daugai
# Processing Record 604 | Tapa
# Processing Record 605 | Ambulu
# City not found. Skipping...
# Processing Record 607 | Trairi
# Processing Record 608 | Qasigiannguit
# City not found. Skipping...
# Processing Record 610 | Orchard Homes
# Processing Record 611 | Chota
# Processing Record 612 | Price
# Processing Record 613 | Toyooka
# Processing Record 614 | Thinadhoo
# Processing Record 615 | Meadow Lake
# Processing Record 616 | Jinchang
# Processing Record 617 | Dayong
# Processing Record 618 | Acarau
# Processing Record 619 | Lamas
# Processing Record 620 | Karatsu
# Processing Record 621 | Karasburg
# Processing Record 622 | Pacifica
# Processing Record 623 | Tha Bo
# Processing Record 624 | Grindavik
# Processing Record 625 | Morondava
# Processing Record 626 | Boden
# Processing Record 627 | Anloga
# Processing Record 628 | Falam
# City not found. Skipping...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Dependencies to export the above to csv.file
import os
import csv

# %%
#use zip function to pair each list together
raw_data_csv = zip(city_id, cities, cloudiness, country, date, humidity, lat, lng, temp, wind_speed)

# %%
# Path for the new file
output_data_file = os.path.join("cities.csv")

# %%
with open(output_data_file, "w") as csvfile:
    csv_writer = csv.writer(csvfile)
    csv_writer.writerow(["City_ID", "City", "Cloudiness", "Country", "Date", "Humidity", "Lat", "Lng", "Max Temp", "Wind Speed"])
    csv_writer.writerows(raw_data_csv)

# %%
city_weather = pd.read_csv(output_data_file)
city_weather_df = city_weather[["City", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Country", "Date"]]
city_weather_df.head(30)
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         umzimvubu -42.88  147.33     66.20        59          75
# 1            hobart -45.87  170.50     46.99        61           0
# 2           dunedin  71.97  102.50     18.07        97         100
# 3          khatanga -19.98   23.42     77.00        44           2
# 4              maun  22.08 -159.32     84.20        66          40
# 5            warqla  14.53   20.92     84.11        17          92
# 6             kapaa -20.23  164.02     75.56        81         100
# 7           biltine  64.86 -147.80     26.60        68          90
# 8              poum   3.07  172.79     82.13        75          80
# 9           college  78.22   15.64     28.40        79          75
# 10       butaritari  17.49   44.13     64.40        33           0
# 11     longyearbyen -16.48 -151.75     78.94        78           0
# 12           najran -53.15  -70.92     48.20        61          75
# 13           faanui -21.36   55.77     73.40        64          75
# 14     punta arenas -31.43  152.92     82.00        27           0
# 15   saint-philippe  69.38  178.42     34.18        87         100
# 16   port macquarie -22.97  -42.03     72.48        94           3
# 17    leningradskiy  60.72 -135.05     41.00        48          20
# 18  arraial do cabo  20.93  -17.03     78.80        69          44
# 19      barentsburg  -9.80 -139.03     77.94        74           3
# 20       whitehorse  48.93 -125.55     55.40        76          40
# 21       nouadhibou  62.23   -6.59     44.60        75          99
# 22           atuona -20.74  116.85     94.60        21           0
# 23         ucluelet -38.00  -57.56     51.80        66           0
# 24         klaksvik  -2.02  147.27     85.98        66         100
# 25         karratha  -3.80  102.27     79.83        77         100
# 26    mar del plata -23.12 -134.97     73.69        81         100
# 27         lorengau   0.38    9.78     78.80        83          40
# 28         bengkulu -33.87  121.90     59.00       100          90
# 29          rikitea  30.95  113.55     59.00        93          90
#
#     Wind Speed Country        Date
# 0        18.34      AU  1602723909
# 1        18.99      NZ  1602724135
# 2        11.50      RU  1602723726
# 3        20.80      BW  1602724136
# 4        11.41      US  1602724136
# 5         8.12      TD  1602724136
# 6         5.79      NC  1602724136
# 7         4.70      US  1602724136
# 8        10.96      KI  1602724136
# 9         3.36      SJ  1602724136
# 10        2.39      SA  1602724061
# 11       11.83      PF  1602724137
# 12       14.99      CL  1602724137
# 13        6.93      RE  1602724137
# 14        1.99      AU  1602724137
# 15        7.83      RU  1602724137
# 16       12.30      BR  1602724137
# 17        2.24      CA  1602723884
# 18       11.41      MR  1602724138
# 19       20.11      PF  1602724138
# 20       11.41      CA  1602724036
# 21        4.70      FO  1602724138
# 22        6.51      AU  1602723883
# 23       11.41      AR  1602724029
# 24        5.82      PG  1602724138
# 25        2.95      ID  1602724060
# 26       18.03      PF  1602724139
# 27        9.17      GA  1602724139
# 28       14.99      AU  1602723926
# 29        4.47      CN  1602724139

# %%
city_weather_df.nunique()
# Out:
# City          573
# Lat           555
# Lng           564
# Max Temp      338
# Humidity       87
# Cloudiness     79
# Wind Speed    288
# Country       116
# Date          386
# dtype: int64

# %%
city_weather_df.describe()
# Out:
#               Lat         Lng    Max Temp   Humidity  Cloudiness  Wind Speed  \
# count  573.000000  573.000000  573.000000  573.00000  573.000000  573.000000
# mean    19.393839   14.989197   62.574625   71.30192   48.954625    8.252443
# std     32.632517   94.339333   18.703902   21.76354   40.638282    5.592090
# min    -54.800000 -179.170000   12.540000    1.00000    0.000000    0.290000
# 25%     -6.550000  -70.760000   48.200000   61.00000    1.000000    3.360000
# 50%     22.170000   19.770000   66.990000   77.00000   40.000000    7.180000
# 75%     45.900000  104.180000   78.800000   87.00000   92.000000   11.410000
# max     78.220000  179.320000  100.400000  100.00000  100.000000   30.290000
#
#                Date
# count  5.730000e+02
# mean   1.602725e+09
# std    5.361597e+02
# min    1.602724e+09
# 25%    1.602724e+09
# 50%    1.602725e+09
# 75%    1.602725e+09
# max    1.602726e+09

# %%
#Use the count function to get the total count for each field and look for miscellaneous values.
city_weather_df.count()
# Out:
# City          573
# Lat           573
# Lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# Country       568
# Date          573
# dtype: int64

# %%
#Use drop function to drop rows that are missing data: dropna(inplace=True)
city_weather_df.dropna(inplace=True)
city_weather_df.count()
# Out:
# C:\Users\Scott Proveucher\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# City          568
# Lat           568
# Lng           568
# Max Temp      568
# Humidity      568
# Cloudiness    568
# Wind Speed    568
# Country       568
# Date          568
# dtype: int64

# %%
#Use nunuique function and compare to the nunique above to see the change after dropping rows.
city_weather_df.nunique()
# Out:
# City          568
# Lat           550
# Lng           559
# Max Temp      335
# Humidity       87
# Cloudiness     79
# Wind Speed    285
# Country       116
# Date          383
# dtype: int64

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
city_weather_df.loc[city_weather_df["Humidity"]>=100].index
# Out:
# Int64Index([ 28,  76, 110, 127, 169, 178, 198, 233, 270, 287, 305, 306, 317,
#             359, 367, 368, 406, 443, 567],
#            dtype='int64')

# %%
#Put the list of indicies into a list.
to_be_dropped = city_weather_df.loc[city_weather_df["Humidity"]>=100].index
to_be_dropped
# Out:
# Int64Index([ 28,  76, 110, 127, 169, 178, 198, 233, 270, 287, 305, 306, 317,
#             359, 367, 368, 406, 443, 567],
#            dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
#Use the dropna function

clean_city_data = city_weat.drop((to_be_dropped), inplace=False)
clean_city_data.head(30)
#City ID 28 was dropped, looks correct.
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0         umzimvubu -42.88  147.33     66.20        59          75
# 1            hobart -45.87  170.50     46.99        61           0
# 2           dunedin  71.97  102.50     18.07        97         100
# 3          khatanga -19.98   23.42     77.00        44           2
# 4              maun  22.08 -159.32     84.20        66          40
# 5            warqla  14.53   20.92     84.11        17          92
# 6             kapaa -20.23  164.02     75.56        81         100
# 7           biltine  64.86 -147.80     26.60        68          90
# 8              poum   3.07  172.79     82.13        75          80
# 9           college  78.22   15.64     28.40        79          75
# 10       butaritari  17.49   44.13     64.40        33           0
# 11     longyearbyen -16.48 -151.75     78.94        78           0
# 12           najran -53.15  -70.92     48.20        61          75
# 13           faanui -21.36   55.77     73.40        64          75
# 14     punta arenas -31.43  152.92     82.00        27           0
# 15   saint-philippe  69.38  178.42     34.18        87         100
# 16   port macquarie -22.97  -42.03     72.48        94           3
# 17    leningradskiy  60.72 -135.05     41.00        48          20
# 18  arraial do cabo  20.93  -17.03     78.80        69          44
# 19      barentsburg  -9.80 -139.03     77.94        74           3
# 20       whitehorse  48.93 -125.55     55.40        76          40
# 21       nouadhibou  62.23   -6.59     44.60        75          99
# 22           atuona -20.74  116.85     94.60        21           0
# 23         ucluelet -38.00  -57.56     51.80        66           0
# 24         klaksvik  -2.02  147.27     85.98        66         100
# 25         karratha  -3.80  102.27     79.83        77         100
# 26    mar del plata -23.12 -134.97     73.69        81         100
# 27         lorengau   0.38    9.78     78.80        83          40
# 29          rikitea  30.95  113.55     59.00        93          90
# 30            ntoum -24.87  113.63     69.80        68          90
#
#     Wind Speed Country        Date
# 0        18.34      AU  1602723909
# 1        18.99      NZ  1602724135
# 2        11.50      RU  1602723726
# 3        20.80      BW  1602724136
# 4        11.41      US  1602724136
# 5         8.12      TD  1602724136
# 6         5.79      NC  1602724136
# 7         4.70      US  1602724136
# 8        10.96      KI  1602724136
# 9         3.36      SJ  1602724136
# 10        2.39      SA  1602724061
# 11       11.83      PF  1602724137
# 12       14.99      CL  1602724137
# 13        6.93      RE  1602724137
# 14        1.99      AU  1602724137
# 15        7.83      RU  1602724137
# 16       12.30      BR  1602724137
# 17        2.24      CA  1602723884
# 18       11.41      MR  1602724138
# 19       20.11      PF  1602724138
# 20       11.41      CA  1602724036
# 21        4.70      FO  1602724138
# 22        6.51      AU  1602723883
# 23       11.41      AR  1602724029
# 24        5.82      PG  1602724138
# 25        2.95      ID  1602724060
# 26       18.03      PF  1602724139
# 27        9.17      GA  1602724139
# 29        4.47      CN  1602724139
# 30       21.92      AU  1602724139

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
from scipy import stats

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Set variables
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Max Temp"]
#Plot scatter plot
plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("City Latitude vs. Max Temperature")
#Save the .png image
plt.savefig("City Latitude vs. Max Temperature.png")
#Show Plot
plt.show()

# %%
#what is the correlation between the two variables
lat = clean_city_data["Lat"]
max_temp = clean_city_data["Max Temp"]
correlation = stats.pearsonr(lat, max_temp)
print(f"The correlation between both factors is {round(correlation[0],2)}")
#what is this plot analyzing
"Each point on the plot represents a city's temperature in relation to their geographic latitude. Cities at latitude 0 or closer to 0 have a higher temperature. There is a negative relationship between latitude and Max Temp."
# Out:
# The correlation between both factors is -0.6
# "Each point on the plot represents a city's temperature in relation to their geographic latitude. Cities at latitude 0 or closer to 0 have a higher temperature. There is a negative relationship between latitude and Max Temp."

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Set variables
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Humidity"]
#Plot scatter plot
plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity")
#Save the .png image
plt.savefig("City Latitude vs. Humidity.png")
#Show Plot
plt.show()

# %%
#what is the correlation between the two variables
lat = clean_city_data["Lat"]
humidity = clean_city_data["Humidity"]
correlation = stats.pearsonr(lat, humidity)
print(f"The correlation between both factors is {round(correlation[0],2)}")
#what is this plot analyzing
"Each point on the plot represents a city's humidity level in relation to their geographic latitude. Cities at a higher latitude with a higher humidity level tend to be clustered to the top right of the plot. There is a positive relationship between latitude and Humidity."
# Out:
# The correlation between both factors is 0.14
# "Each point on the plot represents a city's humidity level in relation to their geographic latitude. Cities at a higher latitude with a higher humidity level tend to be clustered to the top right of the plot. There is a positive relationship between latitude and Humidity."

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Set variables
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Cloudiness"]
#Plot scatter plot
plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness")
#Save the .png image
plt.savefig("City Latitude vs. Cloudiness.png")
#Show Plot
plt.show()

# %%
#what is this plot analyzing
#what is the correlation between the two variables
lat = clean_city_data["Lat"]
cloudiness = clean_city_data["Cloudiness"]
correlation = stats.pearsonr(lat, cloudiness)
print(f"The correlation between both factors is {round(correlation[0],2)}")
#what is this plot analyzing
"Each point on the plot represents a city's cloudiness in relation to their geographic latitude. There is a positive relationship between latitude and cloudiness."
# Out:
# The correlation between both factors is 0.11
# "Each point on the plot represents a city's cloudiness in relation to their geographic latitude. There is a positive relationship between latitude and cloudiness."

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Set variables
x_values = clean_city_data["Lat"]
y_values = clean_city_data["Wind Speed"]
#Plot scatter plot
plt.scatter(x_values,y_values)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs. Wind Speed")
#Save the .png image
plt.savefig("City Latitude vs. Cloudiness.png")
#Show Plot
plt.show()

# %%
#what is the correlation between the two variables
lat = clean_city_data["Lat"]
wind_speed = clean_city_data["Wind Speed"]
correlation = stats.pearsonr(lat, wind_speed)
print(f"The correlation between both factors is {round(correlation[0],2)}")
#what is this plot analyzing
"Each point on the plot represents a city's wind speed in relation to their geographic latitude. There is hardly a correlation between latitude and wind speed but, it is positive."
# Out:
# The correlation between both factors is 0.02
# "Each point on the plot represents a city's wind speed in relation to their geographic latitude. There is hardly a correlation between latitude and wind speed but, it is positive."

# %% [markdown]
# ## Linear Regression

# %%
#Need to create a dateframe for cities located in Northern Hemisphere
northern_hemisphere = clean_city_data.loc[clean_city_data["Lat"]>=0.0]
northern_hemisphere.head(20)
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 2           dunedin  71.97  102.50     18.07        97         100
# 4              maun  22.08 -159.32     84.20        66          40
# 5            warqla  14.53   20.92     84.11        17          92
# 7           biltine  64.86 -147.80     26.60        68          90
# 8              poum   3.07  172.79     82.13        75          80
# 9           college  78.22   15.64     28.40        79          75
# 10       butaritari  17.49   44.13     64.40        33           0
# 15   saint-philippe  69.38  178.42     34.18        87         100
# 17    leningradskiy  60.72 -135.05     41.00        48          20
# 18  arraial do cabo  20.93  -17.03     78.80        69          44
# 20       whitehorse  48.93 -125.55     55.40        76          40
# 21       nouadhibou  62.23   -6.59     44.60        75          99
# 27         lorengau   0.38    9.78     78.80        83          40
# 29          rikitea  30.95  113.55     59.00        93          90
# 32        yingcheng  73.51   80.55     29.61        91         100
# 33        carnarvon  65.61  -37.64     35.60        92         100
# 34        busselton   5.35   48.53     79.97        77         100
# 35           dikson  17.25   99.67     78.80        94          75
# 36         tasiilaq   7.77  -72.22     66.02        87         100
# 38        sukhothai  60.72  -46.03     35.60        80           0
#
#     Wind Speed Country        Date
# 2        11.50      RU  1602723726
# 4        11.41      US  1602724136
# 5         8.12      TD  1602724136
# 7         4.70      US  1602724136
# 8        10.96      KI  1602724136
# 9         3.36      SJ  1602724136
# 10        2.39      SA  1602724061
# 15        7.83      RU  1602724137
# 17        2.24      CA  1602723884
# 18       11.41      MR  1602724138
# 20       11.41      CA  1602724036
# 21        4.70      FO  1602724138
# 27        9.17      GA  1602724139
# 29        4.47      CN  1602724139
# 32       20.45      RU  1602724139
# 33        3.36      GL  1602724139
# 34       15.88      SO  1602724139
# 35        2.24      TH  1602723948
# 36        1.50      VE  1602724140
# 38        3.36      GL  1602724140

# %%
#Need to create a dateframe for cities located in Southern Hemisphere
southern_hemisphere = clean_city_data.loc[clean_city_data["Lat"]<=0.0]
southern_hemisphere.head(20)
# Out:
#                       City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0                umzimvubu -42.88  147.33     66.20        59          75
# 1                   hobart -45.87  170.50     46.99        61           0
# 3                 khatanga -19.98   23.42     77.00        44           2
# 6                    kapaa -20.23  164.02     75.56        81         100
# 11            longyearbyen -16.48 -151.75     78.94        78           0
# 12                  najran -53.15  -70.92     48.20        61          75
# 13                  faanui -21.36   55.77     73.40        64          75
# 14            punta arenas -31.43  152.92     82.00        27           0
# 16          port macquarie -22.97  -42.03     72.48        94           3
# 19             barentsburg  -9.80 -139.03     77.94        74           3
# 22                  atuona -20.74  116.85     94.60        21           0
# 23                ucluelet -38.00  -57.56     51.80        66           0
# 24                klaksvik  -2.02  147.27     85.98        66         100
# 25                karratha  -3.80  102.27     79.83        77         100
# 26           mar del plata -23.12 -134.97     73.69        81         100
# 30                   ntoum -24.87  113.63     69.80        68          90
# 31               esperance -33.65  115.33     64.99        50           8
# 37                   hobyo  -0.74  -90.35     69.01        94          83
# 41  grand river south east -26.65   15.16     71.02        28           0
# 47              lavrentiya -14.48   35.26     70.57        60          68
#
#     Wind Speed Country        Date
# 0        18.34      AU  1602723909
# 1        18.99      NZ  1602724135
# 3        20.80      BW  1602724136
# 6         5.79      NC  1602724136
# 11       11.83      PF  1602724137
# 12       14.99      CL  1602724137
# 13        6.93      RE  1602724137
# 14        1.99      AU  1602724137
# 16       12.30      BR  1602724137
# 19       20.11      PF  1602724138
# 22        6.51      AU  1602723883
# 23       11.41      AR  1602724029
# 24        5.82      PG  1602724138
# 25        2.95      ID  1602724060
# 26       18.03      PF  1602724139
# 30       21.92      AU  1602724139
# 31        9.10      AU  1602724139
# 37        3.00      EC  1602724140
# 41       11.63     NaN  1602724140
# 47       12.17      MW  1602724141

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create the variables for the scatterplot as data frames
latitude_northern = northern_hemisphere["Lat"]
max_temp_northern = northern_hemisphere["Max Temp"]

#state the slope and intercept using stats regression formula
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(latitude_northern, max_temp_northern)
regression_values = latitude_northern * slope + intercept
#plot scatter plot
northern_lat_vs_max_temp_scatter = northern_hemisphere.plot(kind='scatter', x="Lat", y = "Max Temp")
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# Plot the regression line
northern_lat_vs_max_temp_scatter.plot(latitude_northern, regression_values, "g-")
plt.show()
plt.tight_layout()

print(line_eq)
# Out:
# y = -0.86x + 91.31

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
